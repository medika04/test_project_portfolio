# %%
! pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\acer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.9.12)
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: C:\Users\acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import psycopg2
from psycopg2 import sql

import psycopg2
import pandas as pd

DB_USERNAME = "postgres"
DB_PASSWORD = "admin"
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "postgres"

conn = psycopg2.connect(
    host=DB_HOST,
    port=DB_PORT,
    database=DB_NAME,
    user=DB_USERNAME,
    password=DB_PASSWORD
)

print("Connection successful!")
# Out:
# Connection successful!

# %%
query = "SELECT * FROM karyawan;"
cursor = conn.cursor()
cursor.execute(query)
rows = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]

df = pd.DataFrame(rows, columns=columns)
df
# Out:
#    id          nama   departemen       gaji
# 0   1  Budi Santoso  Engineering  8000000.0
# 1   2   Siti Rahayu    Marketing  6500000.0
# 2   3  Andi Pratama      Finance  7000000.0
# 3   4  Dewi Lestari           HR  6000000.0
# 4   5  Rizky Fadhil        Sales  5500000.0
